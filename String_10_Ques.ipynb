# %%
Input a string and a character:Find position using find
If not found, print "Character not present"

Remove all characters after a given symbol (including symbol).
Example:abc@xyz → abc

Reverse each word individually, not the entire sentence

Find the longest word in a sentence.

Print characters present at odd positions only (0-based indexing).
Example:Input: abcdef
Output: bdf

Replace all occurrences of a given character with another character without using replace().
    
Print the difference between first and last occurrence index of a character.
    Input- s = "programming",ch = "g"
    O/P - Difference = 10 - 3 = 7

Check whether one string is a rotation of another.
Example:abcde → cdeab  (True)

Given two strings, create a new string by taking alternate characters from both.
Example:abc, xyz → axbycz

Reverse only alphabetic characters and keep digits/symbols in the same place.
Example:a1b2c3 → c1b2a3
